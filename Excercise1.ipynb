# %%
""" Create a variable to store your name and print a greeting message using it 
example output
Hello, Akhila!"""
# Out:
# ' Create a variable to store your name and print a greeting message using it \nexample output\nHello, Akhila!'

# %%
name = 'Akhila'

# %%
print(f"Hello",name)
# Out:
# Hello Akhila
